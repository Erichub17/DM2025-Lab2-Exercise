# %% [markdown]
# ### **Student Information**
# Name:馬光榮
#
# Student ID:112072282
#
# GitHub ID:Erichub17
#
# Kaggle name: YE MIN AUNG
#
# Kaggle private scoreboard snapshot:![截圖 2025-12-02 14.07.51.png](data:image/png;base64,...)
# ![截圖 2025-12-02 11.21.32.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# # **Instructions**

# %% [markdown]
# For this lab we have divided the assignments into **three phases/parts**. The `first two phases` refer to the `exercises inside the Master notebooks` of the [DM2025-Lab2-Exercise Repo](https://github.com/difersalest/DM2025-Lab2-Exercise.git). The `third phase` refers to an `internal Kaggle competition` that we are gonna run among all the Data Mining students. Together they add up to `100 points` of your grade. There are also some `bonus points` to be gained if you complete `extra exercises` in the lab **(bonus 15 pts)** and in the `Kaggle Competition report` **(bonus 5 pts)**.
#
# **Environment recommendations to solve lab 2:**
# - **Phase 1 exercises:** Need GPU for training the models explained in that part, if you don't have a GPU in your laptop it is recommended to run in Colab or Kaggle for a faster experience, although with CPU they can still be solved but with a slower execution.
# - **Phase 2 exercises:** We use Gemini's API so everything can be run with only CPU without a problem.
# - **Phase 3 exercises:** For the competition you will probably need GPU to train your models, so it is recommended to use Colab or Kaggle if you don't have a laptop with a dedicated GPU.
# - **Optional Ollama Notebook (not graded):** You need GPU, at least 4GB of VRAM with 16 GB of RAM to run the local open-source LLM models.
#
# ## **Phase 1 (30 pts):**
#
# 1. __Main Exercises (25 pts):__ Do the **take home exercises** from Sections: `1. Data Preparation` to `9. High-dimension Visualization: t-SNE and UMAP`, in the [DM2025-Lab2-Master-Phase_1 Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_1.ipynb). Total: `8 exercises`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 3th, 11:59 pm, Monday)`**
#
# 2. **Code Comments (5 pts):** **Tidy up the code in your notebook**.
#
# ## **Phase 2 (30 pts):**
#
# 1. **Main Exercises (25 pts):** Do the remaining **take home exercises** from Section: `2. Large Language Models (LLMs)` in the [DM2025-Lab2-Master-Phase_2_Main Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Main.ipynb). Total: `5 exercises required from sections 2.1, 2.2, 2.4 and 2.6`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**
#
# 2. **Code Comments (5 pts):** **Tidy up the code in your notebook**.
#
# 3. **`Bonus (15 pts):`** Complete the bonus exercises in the [DM2025-Lab2-Master-Phase_2_Bonus Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Bonus.ipynb) and [DM2025-Lab2-Master-Phase_2_Main Notebook](https://github.com/difersalest/DM2025-Lab2-Exercise/blob/main/DM2025-Lab2-Master-Phase_2_Main.ipynb) `where 2 exercises are counted as bonus from sections 2.3 and 2.5 in the main notebook`. Total: `7 exercises`. Commit your code and submit the repository link to NTU Cool **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**
#
# ## **Phase 3 (40 pts):**
#
# 1. **Kaggle Competition Participation (30 pts):** Participate in the in-class **Kaggle Competition** regarding Emotion Recognition on Twitter by clicking in this link: **[Data Mining Class Kaggle Competition](https://www.kaggle.com/t/3a2df4c6d6b4417e8bf718ed648d7554)**. The scoring will be given according to your place in the Private Leaderboard ranking:
#     - **Bottom 40%**: Get 20 pts of the 30 pts in this competition participation part.
#
#     - **Top 41% - 100%**: Get (0.6N + 1 - x) / (0.6N) * 10 + 20 points, where N is the total number of participants, and x is your rank. (ie. If there are 100 participants and you rank 3rd your score will be (0.6 * 100 + 1 - 3) / (0.6 * 100) * 10 + 20 = 29.67% out of 30%.)
#     Submit your last submission **`BEFORE the deadline (Nov. 24th, 11:59 pm, Monday)`**. Make sure to take a screenshot of your position at the end of the competition and store it as `pic_ranking.png` under the `pics` folder of this repository and rerun the cell **Student Information**.
#
# 2. **Competition Report (10 pts)** A report section to be filled in inside this notebook in Markdown Format, we already provided you with the template below. You need to describe your work developing the model for the competition. The report should include a section describing briefly the following elements:
# * Your preprocessing steps.
# * The feature engineering steps.
# * Explanation of your model.
#
# * **`Bonus (5 pts):`**
#     * You will have to describe more detail in the previous steps.
#     * Mention different things you tried.
#     * Mention insights you gained.
#
# [Markdown Guide - Basic Syntax](https://www.markdownguide.org/basic-syntax/)
#
# **`Things to note for Phase 3:`**
#
# * **The code used for the competition should be in this Jupyter Notebook File** `DM2025-Lab2-Homework.ipynb`.
#
# * **Push the code used for the competition to your repository**.
#
# * **The code should have a clear separation for the same sections of the report, preprocessing, feature engineering and model explanation. Briefly comment your code for easier understanding, we provide a template at the end of this notebook.**
#
# * Showing the kaggle screenshot of the ranking plus the code in this notebook will ensure the validity of your participation and the report to obtain the corresponding points.
#
# After the competition ends you will have two days more to submit the `DM2025-Lab2-Homework.ipynb` with your report in markdown format and your code. Do everything **`BEFORE the deadline (Nov. 26th, 11:59 pm, Wednesday) to obtain 100% of the available points.`**
#
# Upload your files to your repository then submit the link to it on the corresponding NTU Cool assignment.
#
# ## **Deadlines:**
#
# ![lab2_deadlines](https://github.com/Erichub17/DM2025-Lab2-Exercise/blob/main/pics/lab2_deadlines.png?raw=1)

# %% [markdown]
# ---
#
# Next you will find the template report with some simple markdown syntax explanations, use it to structure your content.
#
# You can delete the syntax suggestions after you use them.
#
# ---

# %% [markdown]
# ***
#
# # **Project Report**
#
# ##1.1 Preprocessing Steps
#
# For this project, I realized that traditional models and deep learning models need different kinds of input. So, I implemented two specific preprocessing pipelines:
#
# ##1. Basic Cleaning (For Naive Bayes & Random Forest)
#
# My goal here was to reduce noise so TF-IDF could work better.
#
# Standardization: I converted all text to lowercase and removed extra whitespaces to make the vocabulary consistent.
#
# Anonymization: I replaced specific user handles (@user) with a generic <USER> token and URLs with <URL>. This prevents the model from overfitting on specific names or links.
#
# Emoji Handling: Instead of removing emojis, I used the emoji library to translate them into text (e.g., 😂 becomes :joy:). This keeps the sentiment information intact.
#
# Hashtags: I appended hashtags to the end of the text to ensure they are treated as important features.
#
# ##2. Context-Aware Cleaning (For RoBERTa Competition Model)
#
# For the deep learning model, I wanted to preserve the emotional context (tone) of the tweets.
#
# Emotional Punctuation: I didn't just remove punctuation. I replaced repeated marks like !! with the special token EXCLAIM and ?? with QUESTION. This helps the model understand intensity and confusion.
#
# Entity Handling: I replaced the placeholder [NAME] with PERSON, @mentions with USER, and links with LINK.
#
# Character Normalization: I reduced repeated characters (e.g., sooooo -> soo) to normalize exaggerated spellings often found in social media text.
#
# HTML Decoding: I also used html.unescape to fix broken characters caused by web encoding.
#
# ##1.2 Feature Engineering Steps
#
# After cleaning the text, I needed to convert it into numbers so the models could learn from it.
#
# ##1. TF-IDF Vectorization
#
# I used TF-IDF (Term Frequency-Inverse Document Frequency) to extract features.
#
# Settings: I set ngram_range=(1, 2), which means I looked at both single words (unigrams) and pairs of words (bigrams). This helps capture phrases like "not happy" which have a different meaning than just "happy".
#
# Feature Limit: I limited the number of features to the top 5,000 to 10,000 most important words to keep the computation efficient while retaining enough information.
#
# ##2. High-Dimensional Visualization (t-SNE & UMAP)
#
# To understand the difficulty of this classification task, I used dimensionality reduction techniques to visualize the data.
#
# t-SNE (2D): I projected the TF-IDF features into a 2D map.
#
# UMAP (3D): I also tried a 3D projection using UMAP to see if the clusters would separate better.
#
# Insight: As shown in the graphs I generated, the data points for different emotions are heavily overlapped. There are no clear, separate clusters. This visual proof told me that simple keyword-based features (like TF-IDF) are likely insufficient for distinguishing between complex emotions, which motivated me to use Deep Learning models (RoBERTa) in the later stages.
#
# ##1.3 Explanation of Your Model
#
# For the final competition, I decided to move away from traditional machine learning and use Deep Learning Transformers, specifically RoBERTa and DistilBERT, to capture the context of the tweets better.
#
# ##1. Model Architecture (Ensemble Approach)
#
# I didn't rely on just one model. I used an Ensemble of two different pre-trained models:
#
# Model A: cardiffnlp/twitter-roberta-base-emotion (Specialized for tweets).
#
# Model B: bhadresh-savani/distilbert-base-uncased-emotion (Faster and lighter).
#
# ##2. Training Strategy
#
# 5-Fold Cross-Validation: To make sure my model wasn't just "lucky," I split the training data into 5 parts and trained the model 5 times. This gave me a much more stable score.
#
# Class Weights: Since the dataset is imbalanced (too much "Joy"), I added Balanced Class Weights to the loss function. This forces the model to pay more attention to minority classes like "Fear" and "Disgust."
#
# ##3. Final Prediction
#
# I combined the predictions from both models using a Weighted Average. The model with the higher validation F1 score got a higher "vote" in the final decision. This pushed my final score to 0.7897, which is way better than the 0.2758 I got from Naive Bayes!
#
# ##2. Bonus Section (5 pts Optional)
#
# ##2.1 Mention Different Things You Tried
#
# I didn't just stick to the default settings; I tried a few advanced techniques to improve my score:
#
# Custom loss function Focal Loss,i implemented a custom SimpleFocalLoss class in PyTorch . I wanted to see if Focal Loss could handle the hard-to-classify examples better than standard Cross-Entropy. Although I ended up using weighted Cross-Entropy for the final submission, writing the custom loss helped me learn a lot about how PyTorch works.
#
# Dynamic ensemble weights,when combining the models, I didn't just average them (A+B)/2. Instead, I calculated the weights based on their validation performance: Weight = (F1_Score)^2. This allowed the model with better performance in each fold to have more influence on the final result, boosting the ensemble accuracy.
#
# Special token engineering, mentioned in the preprocessing step, I manually added tokens like EXCLAIM and QUESTION to the tokenizer's vocabulary. This was an experiment to see if explicitly telling the model about punctuation intensity would help.
#
# ##2.2 Mention Insights You Gained
#
# Naive Bayes (F1: 0.2758): Accuracy is Misleading
# My Naive Bayes model achieved a high accuracy of 58.39%, but it was actually failing. The confusion matrix shows it was heavily biased towards the majority class "Joy" (Recall: 93%), while failing completely on "Disgust" (Recall: 0%) and "Sadness" (Recall: 4%). This taught me that accuracy is a terrible metric for imbalanced datasets.
#
# Random Forest (F1: 0.3550): The Trade-off of Fairness
# By using class_weight='balanced', the Random Forest model behaved very differently. Its accuracy dropped to 43.29%, but the Macro F1 score improved to 0.3550. Unlike Naive Bayes, it actually tried to learn minority classes (Recall for "Fear" rose to 52%, and "Surprise" to 53%), but at the cost of confusing "Joy" (Recall dropped to 42%) with other emotions.
#
# Deep Learning (F1: 0.7897): Context is King
# Neither of the traditional models could truly separate similar emotions like "Anger" and "Joy" effectively because they relied on keywords (TF-IDF). The Deep Learning ensemble was the only approach that understood the context and tone of the sentences, achieving a high F1 score of 0.7897 and solving the classification problem effectively.

# %% [markdown]
# **`From here on starts the code section for the competition.`**
#
# ---

# %% [markdown]
# # **Competition Code**
#
# ## 1. Preprocessing Steps

# %%
### Add the code related to the preprocessing steps in cells inside this section

# %%
# !pip uninstall -y transformers
# Out:
# Found existing installation: transformers 4.57.2
# Uninstalling transformers-4.57.2:
#   Successfully uninstalled transformers-4.57.2

# %%
# !pip install "transformers==4.55.0" "accelerate==0.34.2" sentencepiece -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 42.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 12.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 39.0 MB/s eta 0:00:00

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, f1_score

from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import Trainer, TrainingArguments

import numpy as np
import pandas as pd

# %%
# Step 1
import os
from google.colab import drive
drive.mount('/content/drive')

# path
base_path = '/content/drive/MyDrive/Colab Notebooks/Phase3data/'

# 3. 檢查路徑和列出檔案
if os.path.exists(base_path):
    print(f"\n path: {base_path}")
    files = os.listdir(base_path)
    print("files:")
    for f in files:
        print(f"  - {f}")
else:
    print(f"\n notfound: {base_path}")
# Out:
# Mounted at /content/drive
#
#  path: /content/drive/MyDrive/Colab Notebooks/Phase3data/
# files:
#   - data_identification.csv
#   - emotion.csv
#   - samplesubmission.csv
#   - final_posts.json
#   - y_train.pkl
#   - y_test.pkl
#   - X_train_tfidf.pkl
#   - X_test_tfidf.pkl
#   - train_cleaned.pkl
#   - test_cleaned.pkl
#   - roberta_submission.csv
#   - submission.csv
#   - submission_ensemble.csv
#   - submission_model2_only.csv

# %%
# Step 2
import warnings
import pandas as pd
import json

warnings.filterwarnings('ignore')

DATA_PATH = '/content/drive/MyDrive/Colab Notebooks/Phase3data/'

# 1. load emotion.csv
emotion_df = pd.read_csv(DATA_PATH + 'emotion.csv')
print(f"✓ emotion.csv 載入完成: {emotion_df.shape}")

# 2. load data_identification.csv (train/test )
data_id_df = pd.read_csv(DATA_PATH + 'data_identification.csv')
print(f"data_identification.csv 載入完成: {data_id_df.shape}")

# 3. load final_posts.json
with open(DATA_PATH + 'final_posts.json', 'r', encoding='utf-8') as f:
    posts_json = json.load(f)
print(f"✓ final_posts.json done: {len(posts_json)} datas")
# Out:
# ✓ emotion.csv 載入完成: (47890, 2)
# data_identification.csv 載入完成: (64171, 2)
# ✓ final_posts.json done: 64171 datas

# %%
# Step 3
# check emotion_df
print("emotion.csv 前 3 筆")
print(emotion_df.head(5))
print()

# 檢查 data_id_df
print("data_identification.csv 前 3 筆 ")
print(data_id_df.head(3))
print()

# 檢查 train/test 分布
print("Train/Test 分布")
print(data_id_df['split'].value_counts())
print()

# 看看 JSON 結構
print("=== final_posts.json 第一筆資料結構 ===")
print(json.dumps(posts_json[0], indent=2, ensure_ascii=False)[:500])
# Out:
# emotion.csv 前 3 筆
#          id emotion
# 0  0x35663e     joy
# 1  0xc78afe    fear
# 2  0x90089c     joy
# 3  0x2ffb63     joy
# 4  0x989146     joy
#
# data_identification.csv 前 3 筆
#          id  split
# 0  0x61fc95   test
# 1  0x35663e  train
# 2  0xc78afe  train
#
# Train/Test 分布
# split
# train    47890
# test     16281
# Name: count, dtype: int64
#
# === final_posts.json 第一筆資料結構 ===
# {
#   "root": {
#     "_type": "post",
#     "_source": {
#       "post": {
#         "post_id": "0x61fc95",
#         "text": "We got the ranch, loaded our guns and sat up till sunrise.",
#         "hashtags": []
#       }
#     }
#   }
# }

# %%
# Step 4 解析 JSON 並合併所有資料

# 從 JSON 中提取 post_id 和 text
posts_list = []

for item in posts_json:
    try:
        # 根據 JSON 結構來自己提取資料
        post_data = item['root']['_source']['post']
        posts_list.append({
            'id': post_data['post_id'],
            'text': post_data['text']
        })
    except KeyError:
        # 結構不符，跳過
        continue

# 轉成的話 DataFrame
posts_df = pd.DataFrame(posts_list)

print(f"✓ 成功解析 {len(posts_df)} 筆 posts")
print()

# 合併三個 DataFrame
print("正在合併資料...")
df = posts_df.merge(data_id_df, on='id', how='inner')
df = df.merge(emotion_df, on='id', how='left')

print(f"合併完成！總共 {len(df)} 筆資料")
print()

# 分離 train 和 test
train_df = df[df['split'] == 'train'].copy()
test_df = df[df['split'] == 'test'].copy()


print(" 最終資料集")
print(f"Training set: {train_df.shape[0]} 筆")
print(f"Test set: {test_df.shape[0]} 筆")
print()

# 檢查 train_df 的 emotion 分布
print("=== Training set 的 Emotion 分布 ===")
print(train_df['emotion'].value_counts())
print()
print(f"Emotion 比例:")
print(train_df['emotion'].value_counts(normalize=True).round(3))
print()
# Out:
# ✓ 成功解析 64171 筆 posts
#
# 正在合併資料...
# 合併完成！總共 64171 筆資料
#
#  最終資料集
# Training set: 47890 筆
# Test set: 16281 筆
#
# === Training set 的 Emotion 分布 ===
# emotion
# joy         23797
# anger       10694
# surprise     6281
# sadness      3926
# fear         2009
# disgust      1183
# Name: count, dtype: int64
#
# Emotion 比例:
# emotion
# joy         0.497
# anger       0.223
# surprise    0.131
# sadness     0.082
# fear        0.042
# disgust     0.025
# Name: proportion, dtype: float64

# %%
# # Step 5 檢查缺失值
print("缺失值檢查 ")
print("Training set:")
print(train_df.isnull().sum())
print()
print("Test set:")
print(test_df.isnull().sum())
# Out:
# 缺失值檢查
# Training set:
# id         0
# text       0
# split      0
# emotion    0
# dtype: int64
#
# Test set:
# id             0
# text           0
# split          0
# emotion    16281
# dtype: int64

# %%
# 檢查前 6 筆資料
print("=== Training set 前 5 筆 ")
print(train_df[['id', 'text', 'emotion']].head())
print()

# 檢查 test_df (應該沒有 emotion 標籤)
print("Test set 前 5 筆 ")
print(test_df[['id', 'text', 'emotion']].head())
print()
# Out:
# === Training set 前 5 筆
#          id                                               text emotion
# 1  0x35663e  I bet there is an army of married couples who ...     joy
# 2  0xc78afe                         This could only end badly.    fear
# 3  0x90089c  My sister squeezed a lime in her milk when she...     joy
# 7  0x2ffb63                                Thank you so much❤️     joy
# 9  0x989146  Stinks because ive been in this program for a ...     joy
#
# Test set 前 5 筆
#          id                                               text emotion
# 0  0x61fc95  We got the ranch, loaded our guns and sat up t...     NaN
# 4  0xaba820         and that got my head bobbing a little bit.     NaN
# 5  0x66e44d                Same. Glad it's not just out store.     NaN
# 6  0xc03cf5  Like always i will wait and see thanks for the...     NaN
# 8  0x02f65a  There's a bit of room between "not loving sub-...     NaN

# %%
#安裝
# !pip install emoji transformers datasets scikit-learn -q
# !pip install emoji -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 25.3 MB/s eta 0:00:00

# %%
# # Step 7 文本清理

import emoji
import re
import pandas as pd

def clean_text_v2(text, hashtags=None):
    """
    基礎文本清理（用於 TF-IDF 和傳統模型）
    """
    if pd.isna(text):
        return ""

    # 1. Emoji 轉文字
    text = emoji.demojize(text, language='en')
    text = text.replace(':', ' ')

    # 2. 保留結構，用特殊 token 替換
    text = re.sub(r'@\w+', '<USER>', text)
    text = re.sub(r'http\S+|www\S+|https\S+', '<URL>', text)

    # 3. 加入 hashtags
    if isinstance(hashtags, list) and len(hashtags) > 0:
        hashtag_text = " ".join(f"#{h}" for h in hashtags if h)
        text = f"{text} {hashtag_text}"

    # 4. 轉小寫
    text = text.lower()

    # 5. 移除多餘空白
    text = re.sub(r'\s+', ' ', text).strip()

    return text

# 清理文本並存入 text_clean
print("\n🔄 清理 Training set...")
train_df['text_clean'] = train_df.apply(
    lambda row: clean_text_v2(row['text'], row.get('hashtags')),
    axis=1
)

print("🔄清理 Test set...")
test_df['text_clean'] = test_df.apply(
    lambda row: clean_text_v2(row['text'], row.get('hashtags')),
    axis=1
)


print(f"  train_df 欄位: {train_df.columns.tolist()}")
print(f"  新增欄位: text_clean")

# 檢查前3筆
print("\n" + "=" * 60)
print("清理前後對比（前 3 筆）")
print("=" * 60)
for i in range(min(3, len(train_df))):
    print(f"\n第 {i+1} 筆")
    print(f"原始文本: {train_df.iloc[i]['text'][:80]}")
    print(f"清理後  : {train_df.iloc[i]['text_clean'][:80]}")


# 對比差異（修正版：只比較原始 vs 新版）

print("=" * 60)
print("清理前後對比（前 3 筆）")
print("=" * 60)
for i in range(min(3, len(train_df))):
    print(f"\n第 {i+1} 筆")
    print(f"原始文本: {train_df.iloc[i]['text'][:100]}")
    print(f"新版清理: {train_df.iloc[i]['text_v2'][:100]}")
    print(f"情緒標籤: {train_df.iloc[i]['emotion']}")

# 檢查文本長度
train_df['text_v2_length'] = train_df['text_v2'].str.split().str.len()
test_df['text_v2_length'] = test_df['text_v2'].str.split().str.len()


print("文本長度統計")

print("\nTraining set:")
print(train_df['text_v2_length'].describe())
print("\nTest set:")
print(test_df['text_v2_length'].describe())
# Out:
# 🔄 清理 Training set...
# 🔄清理 Test set...
#   train_df 欄位: ['id', 'text', 'split', 'emotion', 'text_v2', 'text_v2_length', 'text_clean']
#   新增欄位: text_clean
#
# ...
# 清理前後對比（前 3 筆）
# ...
#
# 第 1 筆
# 原始文本: I bet there is an army of married couples who did the same exact thing.
# 清理後  : i bet there is an army of married couples who did the same exact thing.
#
# 第 2 筆
# 原始文本: This could only end badly.
# 清理後  : this could only end badly.
#
# 第 3 筆
# 原始文本: My sister squeezed a lime in her milk when she was 12. Same thing happened, but
# 清理後  : my sister squeezed a lime in her milk when she was 12. same thing happened, but
# ...
# 清理前後對比（前 3 筆）
# ...
#
# 第 1 筆
# 原始文本: I bet there is an army of married couples who did the same exact thing.
# 新版清理: i bet there is an army of married couples who did the same exact thing.
# 情緒標籤: joy
#
# 第 2 筆
# 原始文本: This could only end badly.
# 新版清理: this could only end badly.
# 情緒標籤: fear
#
# 第 3 筆
# ...

# %%
# Step 8 Duplicate Check
import matplotlib.pyplot as plt
from collections import Counter
import seaborn as sns

print("(Duplicate Check)")
train_dup_count = train_df.duplicated(subset=['text']).sum()
train_dup_rate = train_dup_count / len(train_df) * 100
print(f"Training Set 重複文本: {train_dup_count} 筆 ({train_dup_rate:.2f}%)")

test_dup_count = test_df.duplicated(subset=['text']).sum()
test_dup_rate = test_dup_count / len(test_df) * 100
print(f"Testing Set 重複文本: {test_dup_count} 筆 ({test_dup_rate:.2f}%)")


#  刪除重複
train_df = train_df.drop_duplicates(subset=['text'], keep='first')
test_df = test_df.drop_duplicates(subset=['text'], keep='first')

print(f"刪除 duplicated 後 Train 筆數: {len(train_df)}")
print(f"刪除 duplicated 後 Test  筆數: {len(test_df)}")
# Out:
# (Duplicate Check)
# Training Set 重複文本: 0 筆 (0.00%)
# Testing Set 重複文本: 0 筆 (0.00%)
# 刪除 duplicated 後 Train 筆數: 47890
# 刪除 duplicated 後 Test  筆數: 16281

# %%
#step  9 統計詞頻

print("\n 正在統計詞頻...")

all_words = ' '.join(train_df['text']).split()
word_freq = Counter(all_words)

# 取前 20 名
common_words = word_freq.most_common(20)
words = [w for w, c in common_words]
counts = [c for w, c in common_words]

#  畫圖
plt.figure(figsize=(12, 6))
sns.barplot(x=counts, y=words, palette='viridis')
plt.title('Top 20 Most Frequent Words ')
plt.xlabel('Frequency')
plt.ylabel('Word')
plt.show()
# Out:
#  正在統計詞頻...

# %% [markdown]
# ## 2. Feature Engineering Steps

# %%
# 1. Feature Engineering Steps - TF-IDF

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle
import os


print("Step 2.1: TF-IDF 特徵提取")

# 建立資料夾（如果不存在）

os.makedirs('./models', exist_ok=True)
os.makedirs('./Phase3data', exist_ok=True)

print(f"  Training set: {len(train_df)} 筆")
print(f"  Test set: {len(test_df)} 筆")
# Out:
# Step 2.1: TF-IDF 特徵提取
#   Training set: 47890 筆
#   Test set: 16281 筆

# %%
# 2. 建立 TF-IDF Vectorizer


tfidf = TfidfVectorizer(max_features=5000, ngram_range=(1, 2), min_df=2, max_df=0.95)

# 改進建議：
tfidf_vectorizer = TfidfVectorizer(
    max_features=10000,  # 增加特徵數
    ngram_range=(1, 3),  # 加入 trigram
    min_df=2,
    max_df=0.9,  # 降低，過濾更多常見詞
    sublinear_tf=True,  # 使用 log scaling
    strip_accents='unicode',
    lowercase=True
)

# %%
# 3. 轉換文本為 TF-IDF 特徵

# 用訓練集來 fit，然後 transform 訓練集和測試集
X_train_tfidf = tfidf_vectorizer.fit_transform(train_df['text_clean'])
X_test_tfidf = tfidf_vectorizer.transform(test_df['text_clean'])

# 取得標籤
y_train = train_df['emotion']
y_test = test_df['emotion']

print(f"\n TF-IDF 轉換完成！")
print(f"  訓練集特徵矩陣: {X_train_tfidf.shape}")
print(f"  測試集特徵矩陣: {X_test_tfidf.shape}")
print(f"  特徵數量: {len(tfidf_vectorizer.get_feature_names_out())} 個詞")
# Out:
#  TF-IDF 轉換完成！
#   訓練集特徵矩陣: (47890, 10000)
#   測試集特徵矩陣: (16281, 10000)
#   特徵數量: 10000 個詞

# %%
# 4. 查看重要的特徵詞

print("\n 前 30 個 TF-IDF 特徵詞範例：")
feature_names = tfidf_vectorizer.get_feature_names_out()
print(feature_names[:30])


# 查看每種情緒的標籤數量

print("\n 訓練集情緒分布：")
print(y_train.value_counts().sort_index())
print(f"\n訓練集比例：")
print((y_train.value_counts(normalize=True) * 100).round(2).sort_index())


# 儲存 TF-IDF vectorizer 和特徵

print("\n 儲存 TF-IDF 相關檔案...")

# 儲存 vectorizer（之後預測新資料會用到）
with open('./models/tfidf_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf_vectorizer, f)

# 儲存轉換後的特徵（方便後續使用）
with open('./Phase3data/X_train_tfidf.pkl', 'wb') as f:
    pickle.dump(X_train_tfidf, f)
with open('./Phase3data/X_test_tfidf.pkl', 'wb') as f:
    pickle.dump(X_test_tfidf, f)
with open('./Phase3data/y_train.pkl', 'wb') as f:
    pickle.dump(y_train, f)
with open('./Phase3data/y_test.pkl', 'wb') as f:
    pickle.dump(y_test, f)

print("✓ 已儲存以下檔案：")
print("  - ./models/tfidf_vectorizer.pkl")
print("  - ./Phase3data/X_train_tfidf.pkl")
print("  - ./Phase3data/X_test_tfidf.pkl")
print("  - ./Phase3data/y_train.pkl")
print("  - ./Phase3data/y_test.pkl")
# Out:
#  前 30 個 TF-IDF 特徵詞範例：
# ['00' '000' '10' '10 10' '10 minutes' '10 years' '100' '1000' '10k' '11'
#  '12' '13' '14' '15' '15 minutes' '15 years' '16' '17' '18' '19' '1st'
#  '20' '20 years' '200' '2016' '2017' '2018' '2019' '2020' '21']
#
#  訓練集情緒分布：
# emotion
# anger       10694
# disgust      1183
# fear         2009
# joy         23797
# sadness      3926
# surprise     6281
# Name: count, dtype: int64
#
# 訓練集比例：
# emotion
# anger       22.33
# disgust      2.47
# fear         4.20
# joy         49.69
# sadness      8.20
# surprise    13.12
# Name: proportion, dtype: float64
#
#  儲存 TF-IDF 相關檔案...
# ✓ 已儲存以下檔案：
#   - ./models/tfidf_vectorizer.pkl
#   - ./Phase3data/X_train_tfidf.pkl
#   - ./Phase3data/X_test_tfidf.pkl
#   - ./Phase3data/y_train.pkl
#   - ./Phase3data/y_test.pkl

# %% [markdown]
# ##Visualization

# %%
# 5. 特徵向量視覺化 t-SNE and UMAP

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.manifold import TSNE
import plotly.express as px
from scipy.sparse import issparse

# 載入 UMAP
try:
    import umap
except ImportError:
    # 僅供參考，您需要在環境中執行安裝
    # !pip install umap-learn
    print("UMAP 模組未安裝，跳過 UMAP 視覺化。")
    umap_installed = False
else:
    umap_installed = True

# 檢查 X_train_tfidf 是否為稀疏矩陣，並轉換
if 'X_train_tfidf' not in globals():
    print(" 錯誤：X_train_tfidf 變數尚未定義。請先執行 TF-IDF 步驟。")

    exit()

if issparse(X_train_tfidf):
    X_matrix = X_train_tfidf.toarray()
    print("ℹ 將 TF-IDF 稀疏矩陣轉換為密集矩陣供 t-SNE/UMAP 使用。")
else:
    X_matrix = X_train_tfidf

# 假設 y_train 是情緒標籤 (pandas Series 或 array)
y_labels = y_train.copy()


# 2.1 t-SNE 2D Projection

# 1. 隨機抽樣， t-SNE（抽 2,000 筆）
SAMPLE_SIZE = 2000
actual_size = min(len(X_matrix), SAMPLE_SIZE)
subset_idx = np.random.choice(len(X_matrix), actual_size, replace=False)

X_subset = X_matrix[subset_idx]
y_subset = y_labels.iloc[subset_idx].reset_index(drop=True)

print(f"\n t-SNE 降維中 (抽取 {actual_size} 筆樣本)...")

# 2. 執行 t-SNE
tsne = TSNE(
    n_components=2,
    perplexity=30,
    learning_rate=200,
    n_iter=1000,
    random_state=42,
    verbose=1,
    n_jobs=-1)

X_tsne_2d = tsne.fit_transform(X_subset)

# 3. 視覺化
tsne_df = pd.DataFrame({
    'x': X_tsne_2d[:, 0],
    'y': X_tsne_2d[:, 1],
    'emotion': y_subset
})

plt.figure(figsize=(10,7))
sns.scatterplot(
    data=tsne_df,
    x='x', y='y',
    hue='emotion',
    palette='tab10',
    s=30,
    alpha=0.8
)

plt.title("TF-IDF vetorize viusal (t-SNE 2D)", fontsize=15)
plt.xlabel("t-SNE  1")
plt.ylabel("t-SNE 2")
plt.legend(title="emotion")
plt.tight_layout()
plt.show()
# Out:
# ℹ 將 TF-IDF 稀疏矩陣轉換為密集矩陣供 t-SNE/UMAP 使用。
#
#  t-SNE 降維中 (抽取 2000 筆樣本)...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.019s...
# [t-SNE] Computed neighbors for 2000 samples in 0.515s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2000
# [t-SNE] Computed conditional probabilities for sample 2000 / 2000
# [t-SNE] Mean sigma: 0.477956
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 149.122528
# [t-SNE] KL divergence after 1000 iterations: 3.738629

# %% [markdown]
# From this 2D plot, we can see that the data points for different emotions are heavily overlapped. There are no clear boundaries between the classes. For example, 'joy' (blue) and 'anger' (orange) are mixed together. This shows that using simple TF-IDF features is not enough to distinguish these emotions effectively, as they likely share similar keywords.

# %%
# 2.4 UMAP 3D 視覺化

if umap_installed:
    # 2. Sampling
    SAMPLE_SIZE_UMAP = 1000
    actual_size_umap = min(len(X_matrix), SAMPLE_SIZE_UMAP)
    indices_umap = np.random.choice(len(X_matrix), actual_size_umap, replace=False)

    # 取出樣本
    X_sample = X_matrix[indices_umap]
    y_sample = y_labels.iloc[indices_umap]

    try:
        text_sample = train_df['text_clean'].iloc[indices_umap].values
    except NameError:
        text_sample = [f"No Text (Index: {i})" for i in indices_umap]


    print(f"\n進行 UMAP 降維 (抽取 {actual_size_umap} 筆樣本, 從 {X_matrix.shape[1]}維 -> 3維)...")

    # 3. 建立 UMAP 模型
    reducer = umap.UMAP(
        n_components=3,
        n_neighbors=15,
        min_dist=0.1,
        metric='cosine',
        random_state=42
    )

    X_umap_3d = reducer.fit_transform(X_sample)

    # 4. 準備繪圖資料
    plot_df = pd.DataFrame({
        'x': X_umap_3d[:, 0],
        'y': X_umap_3d[:, 1],
        'z': X_umap_3d[:, 2],
        'emotion': y_sample.values,
        'text': text_sample
    })

    # 5. 畫出互動式 3D 散佈圖
    print("生成 UMAP 3D 互動圖表中...")
    fig = px.scatter_3d(
        plot_df, x='x', y='y', z='z',
        color='emotion',
        hover_data=['text'],
        opacity=0.7,
        title=f'TF-IDF Vectors - UMAP 3D Projection',
        color_discrete_sequence=px.colors.qualitative.Bold
    )

    # 6. 調整版面，讓圖例顯示出來
    fig.update_layout(
        # 1. 強制設定圖表寬度與高度
        width=1100,
        height=800,

        # 2. 調整邊界 (Margin): r=200 代表右邊留 200px 給圖例
        margin=dict(l=10, r=200, b=10, t=50),

        # 3. 設定圖例字體大小
        legend=dict(
            title_font_family="Arial",
            font=dict(size=14),
            itemsizing='constant'
        )
    )

    fig.update_traces(marker=dict(size=4))
    fig.show()
else:
    print("\n忽略 UMAP 視覺化：請先安裝 umap-learn 函式庫。")
# Out:
# 進行 UMAP 降維 (抽取 1000 筆樣本, 從 10000維 -> 3維)...
# 生成 UMAP 3D 互動圖表中...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# I used UMAP to project the TF-IDF features into a 3D space to see if the emotions would separate better than in 2D. However, the result still shows a dense cloud where different colors (emotions) are mixed together. There are no distinct clusters for each emotion. This confirms that emotions share very similar keywords, making them hard to distinguish using simple methods. This overlap explains why we need advanced deep learning models like RoBERTa to understand the context better

# %% [markdown]
# ## 3. Model Implementation Steps

# %%
### Add the code related to the model implementation steps in cells inside this section

# %%
# 3. Model Implementation for baseline

# Step 1: 切分訓練集和驗證集 (用於 ML)

from sklearn.model_selection import train_test_split

# 使用 train_df（已經清理過的資料）
train_split, val_split = train_test_split(
    train_df,
    test_size=0.25,
    random_state=42,
    stratify=train_df['emotion']
)

print(f"\n資料切分完成:")
print(f"  Training set: {len(train_split)} 筆")
print(f"  Validation set: {len(val_split)} 筆")


# Step 2: 提取文本和標籤

X_train_text = train_split['text_clean'].values
X_val_text = val_split['text_clean'].values
y_train = train_split['emotion'].values
y_val = val_split['emotion'].values

print(f"\n 文本和標籤準備完成")


# Step 3: TF-IDF 特徵提取（用於傳統 ML）

from sklearn.feature_extraction.text import TfidfVectorizer

# 建立 TF-IDF vectorizer（使用較簡單的參數）
tfidf_ml = TfidfVectorizer(
    max_features=5000,
    ngram_range=(1, 2),
    min_df=2,
    max_df=0.95
)

# 轉換訓練集和驗證集
X_train_tfidf = tfidf_ml.fit_transform(X_train_text)
X_val_tfidf = tfidf_ml.transform(X_val_text)

print(f"\n TF-IDF 轉換完成:")
print(f"  X_train_tfidf: {X_train_tfidf.shape}")
print(f"  X_val_tfidf: {X_val_tfidf.shape}")
print(f"  y_train: {len(y_train)}")
print(f"  y_val: {len(y_val)}")
# Out:
# 資料切分完成:
#   Training set: 35917 筆
#   Validation set: 11973 筆
#
#  文本和標籤準備完成
#
#  TF-IDF 轉換完成:
#   X_train_tfidf: (35917, 5000)
#   X_val_tfidf: (11973, 5000)
#   y_train: 35917
#   y_val: 11973

# %% [markdown]
# ##1. Naive Bayes Model Implementation

# %%
# 1. Naive Bayes Model Implementation

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score

# 定義繪圖函數
def plot_confusion_matrix(cm, classes, title='Confusion Matrix', cmap=plt.cm.Blues, normalize=False):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        title = title + ' (Normalized)'
    else:
        title = title + ' (Count)'

    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='.2f' if normalize else 'd', cmap=cmap,
                xticklabels=classes, yticklabels=classes, square=True)
    plt.title(title, fontsize=16)
    plt.ylabel('True Label', fontsize=14)
    plt.xlabel('Predicted Label', fontsize=14)
    plt.xticks(rotation=45, ha='right')
    plt.show()

# 1. 資料準備 (補上切分動作)

# 優先使用 text_clean，如果沒有就用 text
text_col = 'text_clean' if 'text_clean' in train_df.columns else 'text'
print(f"使用欄位: {text_col}")

# 手動切分 25% 作為驗證集
X_train_text = train_split['text_clean'].values
X_val_text = val_split['text_clean'].values
y_train = train_split['emotion'].values
y_val = val_split['emotion'].values
print(f"資料切分完成: Train={len(X_train_text)}, Val={len(X_val_text)}")

# --- 2. TF-IDF 特徵提取 ---
print("\n初始化 TF-IDF Vectorizer...")
tfidf = TfidfVectorizer(max_features=10000, ngram_range=(1, 2))

# 轉換文本
X_train = tfidf.fit_transform(X_train_text)
X_test  = tfidf.transform(X_val_text)
# y_train 和 y_val 已經在上面定義好了

# --- 3. 訓練 Naive Bayes 模型 ---
print("開始訓練 Naive Bayes 模型...")
NB_model = MultinomialNB(alpha=0.5)
NB_model.fit(X_train, y_train)

# 預測
y_test_pred_nb = NB_model.predict(X_test)

#4. 評估結果
acc_test_nb = accuracy_score(y_val, y_test_pred_nb)
f1_macro_nb = f1_score(y_val, y_test_pred_nb, average='macro')

print("\n Naive Bayes 結果 ")
print(f"Validation Accuracy: {acc_test_nb:.4f}")
print(f"F1 (Macro): {f1_macro_nb:.4f}")

print("\n Classification Report ")
print(classification_report(y_val, y_test_pred_nb, digits=4))

#5. 畫混淆矩陣 (Confusion Matrix)
# 定義標籤順序
emotion_labels = ['anger', 'disgust', 'fear', 'joy', 'sadness', 'surprise']

# 計算矩陣
cm_nb = confusion_matrix(y_val, y_test_pred_nb, labels=emotion_labels)

# 畫圖 (Normalized)
plot_confusion_matrix(
    cm_nb,
    classes=emotion_labels,
    title='Naive Bayes - Confusion Matrix',
    normalize=True
)
# Out:
# 使用欄位: text_clean
# 資料切分完成: Train=35917, Val=11973
#
# 初始化 TF-IDF Vectorizer...
# 開始訓練 Naive Bayes 模型...
#
#  Naive Bayes 結果
# Validation Accuracy: 0.5839
# F1 (Macro): 0.2758
#
#  Classification Report
#               precision    recall  f1-score   support
#
#        anger     0.5613    0.4162    0.4780      2674
#      disgust     1.0000    0.0034    0.0067       296
#         fear     0.6481    0.0697    0.1259       502
#          joy     0.5865    0.9336    0.7204      5949
#      sadness     0.7200    0.0367    0.0698       982
#     surprise     0.6072    0.1605    0.2539      1570
#
#     accuracy                         0.5839     11973
#    macro avg     0.6872    0.2700    0.2758     11973
# weighted avg     0.6073    0.5839    0.5092     11973

# %% [markdown]
# ## Naive Bayes Model Analysis
#
# In my Naive Bayes model, I got a Validation Accuracy of **58.39%**, but honestly, this number is kind of misleading. The Macro F1-score is only **0.2758**, which shows the model isn't actually doing a good job.
#
# When I looked at the Confusion Matrix, I found the main problem: **Class Imbalance**.
#
# Basically, the model is super biased toward 'Joy'. It predicts 'joy' for almost everything! It got **93% of the 'joy' cases right** (recall: 0.9336), but that's just because it keeps guessing 'joy' and ignoring the other emotions.
#
# For the minority classes, it failed completely:
#
# - **Disgust**: It got **0% right**. Zero! 66% of them were wrongly labeled as 'joy'.
# - **Sadness**: It only got **4% right** (recall: 0.0367). Most of them (78%) were misclassified as 'joy'.
# - **Fear**: It only got **7% right** (recall: 0.0697). Again, mostly guessed as 'joy' (71%).
#
# You can see this clearly in the picture—there is a huge **vertical dark blue column under 'joy'**. This proves the model is just relying on the fact that 'joy' is the most common emotion and isn't really learning how to tell the difference between them.
#
# That's why this model isn't good enough for this task.

# %% [markdown]
# ## 2: Random Forest + class_weight=balanced

# %%
import pandas as pd
import pickle
import os
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    accuracy_score,
    classification_report,
    confusion_matrix,
    f1_score
)
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 建立儲存結果的資料夾
os.makedirs('./results', exist_ok=True)

print(" 2: Random Forest + class_weight=balanced")

# 1. 切分訓練集和驗證集 (這裡維持你原本的 test_size=0.25)
print("資料切分中...")
# 優先檢測是否有清理過的文本欄位
col_to_use = 'text_clean' if 'text_clean' in train_df.columns else 'text'
print(f"使用欄位: {col_to_use}")

train_split, val_split = train_test_split(
    train_df,
    test_size=0.25,
    random_state=42,
    stratify=train_df['emotion']
)

X_train_text = train_split[col_to_use].values
X_val_text = val_split[col_to_use].values
y_train = train_split['emotion'].values
y_val = val_split['emotion'].values

# 2. TF-IDF 特徵提取
print("\nTF-IDF 特徵提取...")
tfidf = TfidfVectorizer(max_features=5000, ngram_range=(1, 2), min_df=2, max_df=0.95)
X_train_tfidf = tfidf.fit_transform(X_train_text)
X_val_tfidf = tfidf.transform(X_val_text)

print(f"TF-IDF 完成")
print(f"  X_train: {X_train_tfidf.shape}")
print(f"  X_val: {X_val_tfidf.shape}")

# 3. 訓練 Random Forest (用 class_weight='balanced')
print("\n訓練 Random Forest (class_weight='balanced')...")
rf_model = RandomForestClassifier(
    n_estimators=500,
    max_depth=30,
    min_samples_split=5,
    min_samples_leaf=2,
    class_weight='balanced',
    max_features='sqrt',
    random_state=42,
    n_jobs=-1,
    verbose=1
)

rf_model.fit(X_train_tfidf, y_train)
print(" 訓練完成！")

# 4. 評估模型
print("\n評估模型...")
y_train_pred = rf_model.predict(X_train_tfidf)
y_val_pred = rf_model.predict(X_val_tfidf)

# 準確率
train_accuracy = accuracy_score(y_train, y_train_pred)
val_accuracy = accuracy_score(y_val, y_val_pred)

print(f"\n準確率 (Accuracy)：")
print(f"  Training: {train_accuracy*100:.2f}%")
print(f"  Validation: {val_accuracy*100:.2f}%")

# F1 Score
train_f1_macro = f1_score(y_train, y_train_pred, average='macro')
val_f1_macro = f1_score(y_val, y_val_pred, average='macro')
train_f1_weighted = f1_score(y_train, y_train_pred, average='weighted')
val_f1_weighted = f1_score(y_val, y_val_pred, average='weighted')

print(f"\nF1 Score：")
print(f"   (Macro):")
print(f"    Training: {train_f1_macro:.4f}")
print(f"    Validation: {val_f1_macro:.4f}")
print(f"  (Weighted):")
print(f"    Training: {train_f1_weighted:.4f}")
print(f"    Validation: {val_f1_weighted:.4f}")

# 詳細報告
print(f"\n詳細分類報告 Validation Set")
print(classification_report(y_val, y_val_pred, digits=4))

# 5. 繪製混淆矩陣
print("\n繪製混淆矩陣...")
cm = confusion_matrix(y_val, y_val_pred)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=sorted(np.unique(y_val)),
            yticklabels=sorted(np.unique(y_val)))
plt.title('Random Forest (class_weight=balanced) - Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.tight_layout()
plt.savefig('./results/rf_balanced_confusion_matrix.png', dpi=300)
plt.show()

# 6. 預測測試集並儲存
print("\n預測測試集...")
# 處理測試集文本
X_test_text = test_df[col_to_use].values
X_test_tfidf = tfidf.transform(X_test_text)
test_predictions = rf_model.predict(X_test_tfidf)

submission = pd.DataFrame({
    'id': test_df['id'],
    'emotion': test_predictions
})
# Out:
#  2: Random Forest + class_weight=balanced
# 資料切分中...
# 使用欄位: text_clean
#
# TF-IDF 特徵提取...
# TF-IDF 完成
#   X_train: (35917, 5000)
#   X_val: (11973, 5000)
#
# 訓練 Random Forest (class_weight='balanced')...
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 176 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 426 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:    4.4s finished
# [Parallel(n_jobs=12)]: Using backend ThreadingBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done  26 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=12)]: Done 176 tasks      | elapsed:    0.2s
#  訓練完成！
#
# 評估模型...
# [Parallel(n_jobs=12)]: Done 426 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=12)]: Done 500 out of 500 | elapsed:    0.4s finished
# ...

# %% [markdown]
# ## Random Forest Model Analysis
#
# In the Random Forest model with `class_weight='balanced'`, I got about **49.99% training accuracy** and **43.29% validation accuracy**, with a Macro F1-score of **0.3550**.
#
# The model works okay on 'joy' (F1: 0.5639) and correctly classified **2,500 'joy' samples**, but it still has big problems:
#
# **What Went Wrong:**
#
# 1. **Still Over-Predicts 'Joy'**: Even with class weighting, the model wrongly predicted 'joy' for:
#    - 865 'anger' samples
#    - 1,081 'surprise' samples
#    - 954 'sadness' samples
#
# 2. **Minority Classes Struggle**:
#    - **Disgust**: F1 = 0.1722 (very poor)
#    - **Sadness**: F1 = 0.2568 (poor)
#    - **Fear**: F1 = 0.3255 (weak)
#
# 3. **Emotions Get Confused**: Similar emotions like 'anger' and 'surprise' are often mixed up (593 and 256 misclassifications respectively).
#
# **Why It's Not Good Enough:**
#
# Random Forest only looks at word frequencies (TF-IDF) and can't understand context. For example, "I'm not happy" and "I'm happy" use similar words but have opposite meanings—Random Forest can't tell the difference.
#
# **Compared to my other models:**
# - Better than Naive Bayes (F1: 0.2758) but not by much
# - Much worse than RoBERTa (F1: ~0.79)
#
# **Conclusion**: Random Forest is a useful baseline, but it's not good enough for nuanced emotion classification. I needed deep learning models like RoBERTa to actually understand what sentences mean.

# %%
# Step 10 定義所有必要的變數


# 1. 先確保 train_df 和 test_df 存在且有 'emotion' 欄位
print("原始資料:")
print(f"  train_df: {train_df.shape}")
print(f"  test_df: {test_df.shape}")

# 2. 建立標籤映射
labels = sorted(train_df['emotion'].dropna().unique().tolist())
label2id = {label: idx for idx, label in enumerate(labels)}
id2label = {idx: label for label, idx in label2id.items()}

# 3. 轉換標籤
y = train_df['emotion'].map(label2id).values

print(f"\n標籤映射建立完成:")
print(f"  情緒類別: {labels}")
print(f"  類別數量: {len(labels)}")

# 現在可以執行檢查了
print("\n 檢查是否都定義了")
print("1. train_df 形狀:", train_df.shape)
print("2. test_df 形狀:", test_df.shape)
print("3.labels:", labels)
print("4.label2id:", label2id)
print("5. id2label:", id2label)
print(" 6. y 形狀:", y.shape)
# Out:
# 原始資料:
#   train_df: (47890, 6)
#   test_df: (16281, 6)
#
# 標籤映射建立完成:
#   情緒類別: ['anger', 'disgust', 'fear', 'joy', 'sadness', 'surprise']
#   類別數量: 6
#
#  檢查是否都定義了
# 1. train_df 形狀: (47890, 6)
# 2. test_df 形狀: (16281, 6)
# 3.labels: ['anger', 'disgust', 'fear', 'joy', 'sadness', 'surprise']
# 4.label2id: {'anger': 0, 'disgust': 1, 'fear': 2, 'joy': 3, 'sadness': 4, 'surprise': 5}
# 5. id2label: {0: 'anger', 1: 'disgust', 2: 'fear', 3: 'joy', 4: 'sadness', 5: 'surprise'}
#  6. y 形狀: (47890,)

# %% [markdown]
# ##  3 -Roberta-base-emotion 和 distilbert-base-uncased-emotion

# %%
import os, json, re, html, emoji, gc
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import f1_score
from sklearn.utils.class_weight import compute_class_weight
from scipy.special import softmax
import torch
import torch.nn as nn
import torch.nn.functional as F
from transformers import (
    AutoTokenizer, AutoConfig, AutoModelForSequenceClassification,
    TrainingArguments, Trainer, EarlyStoppingCallback, set_seed,
    DataCollatorWithPadding
)
from datasets import Dataset


# 1. 簡單但不同的文本預處理


def preprocess_text(text, hashtags=None):
    """簡單穩定的預處理"""
    text = html.unescape(str(text))

    # 保留情緒符號（不同策略）
    text = re.sub(r'!{2,}', ' EXCLAIM ', text)
    text = re.sub(r'\?{2,}', ' QUESTION ', text)

    # 標準化
    text = re.sub(r'http\S+|www\.\S+', 'LINK', text)
    text = re.sub(r'@\w+', 'USER', text)
    text = re.sub(r'\[NAME\]', 'PERSON', text, flags=re.IGNORECASE)

    # Emoji 轉換
    text = emoji.demojize(text, language='en')
    text = text.replace(':', ' ')

    # 重複字符（不同方法）
    text = re.sub(r'(.)\1{3,}', r'\1\1', text)

    # Hashtag
    if hashtags and isinstance(hashtags, list):
        tags = ' '.join([str(h).replace('#', '') for h in hashtags if h])
        text = f"{text} {tags}"

    # 清理
    text = re.sub(r'\s+', ' ', text).strip()
    return text



# 2. Focal Loss（

class SimpleFocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2.0):
        super().__init__()
        self.alpha = alpha
        self.gamma = gamma

    def forward(self, inputs, targets):
        ce_loss = F.cross_entropy(inputs, targets, reduction='none')
        p_t = torch.exp(-ce_loss)
        loss = self.alpha * (1 - p_t) ** self.gamma * ce_loss
        return loss.mean()


# 3. 自定義 Trainer


# SimpleTrainer
class SimpleTrainer(Trainer):
    def __init__(self, class_weight=None, use_focal=False, **kwargs):
        super().__init__(**kwargs)
        self.class_weight = class_weight
        self.use_focal = use_focal
        if use_focal:
            self.focal_loss = SimpleFocalLoss()

    # 解決 keep_torch_compile 問題
    def _wrap_model(self, model, training=True, dataloader=None):
        if self.args.use_cpu:
            model = model.to(self.args.device)
        if not training:
            return model
        if hasattr(self, 'accelerator'):
            return self.accelerator.prepare(model)
        return model

    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        labels = inputs.pop("labels")
        outputs = model(**inputs)
        logits = outputs.logits

        if self.use_focal:
            loss = self.focal_loss(logits, labels)
        else:
            weight = None
            if self.class_weight is not None:
                weight = torch.tensor(self.class_weight,
                                    dtype=torch.float32,
                                    device=logits.device)
            loss = F.cross_entropy(logits, labels, weight=weight)

        return (loss, outputs) if return_outputs else loss

# 4. 計算 F1 評估指標


def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=-1)
    f1_macro = f1_score(labels, preds, average='macro')
    f1_micro = f1_score(labels, preds, average='micro')
    return {'f1_macro': f1_macro, 'f1_micro': f1_micro}


# 5. 主訓練函數

def train_single_model(
    model_name,
    train_df,
    test_df,
    label2id,
    n_splits=5,
    lr=2e-5,
    epochs=4,
    batch_size=16,
    max_len=160,
    seed=42
):


    print(f"\n{'='*60}")
    print(f"訓練: {model_name}")
    print(f"{'='*60}\n")

    # Tokenizer
    tokenizer = AutoTokenizer.from_pretrained(model_name, use_fast=True)

    # 添加特殊 token
    new_tokens = ['LINK', 'USER', 'PERSON', 'EXCLAIM', 'QUESTION']
    new_tokens = [t for t in new_tokens if t not in tokenizer.get_vocab()]
    if new_tokens:
        tokenizer.add_tokens(new_tokens)
        print(f"新增 tokens: {new_tokens}")

    # 準備標籤
    y = train_df['emotion'].map(label2id).values

    # 初始化
    skf = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=seed)
    oof_probs = np.zeros((len(train_df), len(label2id)))
    test_probs = np.zeros((len(test_df), len(label2id)))

    # K-Fold 訓練
    for fold, (tr_idx, va_idx) in enumerate(skf.split(train_df, y), 1):
        print(f"\n--- Fold {fold}/{n_splits} ---")

        # 分割數據
        train_texts = train_df.iloc[tr_idx]['text'].tolist()
        train_labels = y[tr_idx].tolist()
        valid_texts = train_df.iloc[va_idx]['text'].tolist()
        valid_labels = y[va_idx].tolist()
        test_texts = test_df['text'].tolist()

        # Tokenize
        train_encodings = tokenizer(
            train_texts,
            truncation=True,
            padding=False,  # 使用 dynamic padding
            max_length=max_len
        )
        valid_encodings = tokenizer(
            valid_texts,
            truncation=True,
            padding=False,
            max_length=max_len
        )
        test_encodings = tokenizer(
            test_texts,
            truncation=True,
            padding=False,
            max_length=max_len
        )

        # 建立 Dataset
        train_dataset = Dataset.from_dict({
            'input_ids': train_encodings['input_ids'],
            'attention_mask': train_encodings['attention_mask'],
            'label': train_labels
        })
        valid_dataset = Dataset.from_dict({
            'input_ids': valid_encodings['input_ids'],
            'attention_mask': valid_encodings['attention_mask'],
            'label': valid_labels
        })
        test_dataset = Dataset.from_dict({
            'input_ids': test_encodings['input_ids'],
            'attention_mask': test_encodings['attention_mask']
        })

        # 計算類別權重
        class_weights = compute_class_weight(
            'balanced',
            classes=np.unique(train_labels),
            y=train_labels
        )

        # 載入模型
        config = AutoConfig.from_pretrained(
            model_name,
            num_labels=len(label2id),
            hidden_dropout_prob=0.1,
            attention_probs_dropout_prob=0.1
        )

        model = AutoModelForSequenceClassification.from_pretrained(
            model_name,
            config=config,
            ignore_mismatched_sizes=True
        )

        # 調整 embedding 大小
        model.resize_token_embeddings(len(tokenizer))

        # 訓練參數
        training_args = TrainingArguments(
            output_dir=f'./output_fold{fold}',
            learning_rate=lr,
            per_device_train_batch_size=batch_size,
            per_device_eval_batch_size=batch_size * 2,
            num_train_epochs=epochs,
            weight_decay=0.01,
            warmup_ratio=0.1,
            lr_scheduler_type='cosine',
            eval_strategy='epoch',
            save_strategy='epoch',
            load_best_model_at_end=True,
            metric_for_best_model='f1_macro',
            greater_is_better=True,
            save_total_limit=1,
            logging_steps=100,
            bf16=True,
            torch_compile=False,
            report_to='none',
            seed=seed,
            dataloader_num_workers=0,
            dataloader_pin_memory=False
        )

        # Data collator for dynamic padding
        data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

        # Trainer
        trainer = SimpleTrainer(
            model=model,
            args=training_args,
            train_dataset=train_dataset,
            eval_dataset=valid_dataset,
            tokenizer=tokenizer,
            data_collator=data_collator,
            compute_metrics=compute_metrics,
            class_weight=class_weights,
            use_focal=False,  # 可改為 True 使用 Focal Loss
            callbacks=[EarlyStoppingCallback(early_stopping_patience=2)]
        )

        # 訓練
        try:
            trainer.train()

            # 預測
            valid_pred = trainer.predict(valid_dataset)
            test_pred = trainer.predict(test_dataset)

            oof_probs[va_idx] = valid_pred.predictions
            test_probs += test_pred.predictions / n_splits

            # 評估
            fold_f1 = f1_score(
                valid_labels,
                np.argmax(valid_pred.predictions, axis=1),
                average='macro'
            )
            print(f"Fold {fold} F1: {fold_f1:.4f}")

        except KeyboardInterrupt:
            print(f"\nFold {fold} 被中斷，跳過...")
            continue
        finally:
            # 清理記憶體
            del model, trainer
            torch.cuda.empty_cache()
            gc.collect()

    # 最終評估
    oof_pred = np.argmax(oof_probs, axis=1)
    final_f1 = f1_score(y, oof_pred, average='macro')
    print(f"\n 整體 OOF F1: {final_f1:.4f}")

    return softmax(oof_probs, axis=1), softmax(test_probs, axis=1)


# 6. 權重平均 Ensemble

def weighted_average_ensemble(all_oof, all_test, y_true):


    weights = []
    for i, oof in enumerate(all_oof):
        pred = np.argmax(oof, axis=1)
        f1 = f1_score(y_true, pred, average='macro')
        weights.append(f1 ** 2)  # 使用平方強化好模型
        print(f"Model {i+1}: F1={f1:.4f}, Weight={f1**2:.4f}")

    # 正規化
    weights = np.array(weights)
    weights = weights / weights.sum()

    # 加權平均
    oof_ensemble = np.average(all_oof, axis=0, weights=weights)
    test_ensemble = np.average(all_test, axis=0, weights=weights)

    final_f1 = f1_score(y_true, np.argmax(oof_ensemble, axis=1), average='macro')
    print(f"\nEnsemble F1: {final_f1:.4f}")

    return oof_ensemble, test_ensemble


# 7. 主程式

if __name__ == "__main__":
    SEED = 42
    set_seed(SEED)


    # train_df, test_df, label2id, id2label

    print("=" * 60)
    print("開始訓練")
    print("=" * 60)

    # 1. 預處理
    print("\n預處理文本...")
    train_df['text'] = train_df.apply(
        lambda r: preprocess_text(r['text'], r.get('hashtags')),
        axis=1
    )
    test_df['text'] = test_df.apply(
        lambda r: preprocess_text(r['text'], r.get('hashtags')),
        axis=1
    )

    # 2. 準備標籤映射
    y = train_df['emotion'].map(label2id).values

    # 3. 訓練多個模型
    models = [
        "cardiffnlp/twitter-roberta-base-emotion",
        "bhadresh-savani/distilbert-base-uncased-emotion"
    ]

    configs = {
        "cardiffnlp/twitter-roberta-base-emotion": {
            "lr": 2e-5, "epochs": 4, "max_len": 160
        },
        "bhadresh-savani/distilbert-base-uncased-emotion": {
            "lr": 3e-5, "epochs": 4, "max_len": 128
        }
    }

    all_oof, all_test = [], []

    for model_name in models:
        cfg = configs[model_name]

        oof, test = train_single_model(
            model_name=model_name,
            train_df=train_df,
            test_df=test_df,
            label2id=label2id,
            n_splits=5,
            lr=cfg['lr'],
            epochs=cfg['epochs'],
            batch_size=8,
            max_len=cfg['max_len'],
            seed=SEED
        )

        all_oof.append(oof)
        all_test.append(test)

    # 4. Ensemble
    print("\n" + "=" * 60)
    print("Ensemble 模型")
    print("=" * 60)

    _, final_test = weighted_average_ensemble(all_oof, all_test, y)

    # 5. csv
    submission = pd.DataFrame({
        'id': test_df['id'],
        'emotion': [id2label[i] for i in np.argmax(final_test, axis=1)]
    })

    submission.to_csv('submission.csv', index=False)
    print("\n 提交檔案已儲存: submission.csv")
# Out:
# ...
# 開始訓練
# ...
#
# 預處理文本...
#
# ...
# 訓練: cardiffnlp/twitter-roberta-base-emotion
# ...
#
# 新增 tokens: ['LINK', 'PERSON', 'EXCLAIM', 'QUESTION']
#
# --- Fold 1/5 ---
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at cardiffnlp/twitter-roberta-base-emotion and are newly initialized because the shapes did not match:
# - classifier.out_proj.weight: found shape torch.Size([4, 768]) in the checkpoint and torch.Size([6, 768]) in the model instantiated
# - classifier.out_proj.bias: found shape torch.Size([4]) in the checkpoint and torch.Size([6]) in the model instantiated
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
#     <div>
#
#       <progress value='34856' max='34856' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [34856/34856 1:09:41, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
# ...

# %%
submission.to_csv('/content/drive/MyDrive/Colab Notebooks/Phase3data/submission.csv', index=False)

# %% [markdown]
# For the final competition, I decided to move away from traditional machine learning and use Deep Learning Transformers, specifically RoBERTa and DistilBERT.
#
# What I did:
#
# Smarter Preprocessing: Instead of just removing everything, I replaced repeated punctuation like !! with a special token EXCLAIM and user handles with USER. This helps the model understand context (like excitement) rather than just treating them as noise.
#
# 5-Fold Cross-Validation: To make sure my model wasn't just 'lucky', I used Stratified K-Fold to train it 5 times on different data splits.
#
# Ensemble Strategy: I trained two different models and combined their predictions using a weighted average. Basically, the model with the higher F1 score got more say in the final decision.
#
# The Results: The improvement is huge!
#
# My single RoBERTa model already hit an F1 score of 0.77.
#
# After combining it with DistilBERT (Ensemble), my final score jumped to 0.7897!
#
# Compared to the 0.28 from Naive Bayes and 0.36 from Random Forest, this proves that for complex emotion detection, we really need models that can 'read' the full sentence structure, not just count keywords.

# %% [markdown]
# ##Thanks and Done
